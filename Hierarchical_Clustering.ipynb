# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivachikkonda02/-Bank-Marketing-Analysis-and-Classification-ML-Project/blob/main/Hierarchical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sns.pairplot(df)

# %%
import scipy.cluster.hierarchy as sch

# %%
sch.dendrogram(sch.linkage(df,method='single',metric='euclidean'))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
Agg=AgglomerativeClustering(n_clusters=3,linkage='single')

# %%
df['predict']=Agg.fit_predict(df)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    predict
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
sns.pairplot(df,hue='predict')
