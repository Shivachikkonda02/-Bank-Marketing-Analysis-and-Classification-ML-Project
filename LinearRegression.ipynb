# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivachikkonda02/-Bank-Marketing-Analysis-and-Classification-ML-Project/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=({
    'area':[2600,3000,3200,3600,4000],
    'bedrooms':[3,4,np.nan,3,5],
    'age':[20,15,18,30,8],
    'price':[550000,565000,610000,595000,760000]
})

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df['bedrooms'].median()
# Out:
# 3.5

# %%
df['bedrooms']=df['bedrooms'].fillna(df['bedrooms'].median())

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.5   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df['bedrooms']=df['bedrooms'].astype(int)

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
import seaborn as sns

# %%
sns.scatterplot(x='area',y='price',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.regplot(x='area',y='price',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
reg.intercept_
# Out:
# 383724.9999999998

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([444400.])

# %%
reg.predict([[2500,3,40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([375775.])
